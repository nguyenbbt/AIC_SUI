# %% [markdown]
# 1. Một format frame_id canonical duy nhất.

# %% [markdown]
# 3. ASR interval → keyframe mapping chính xác.

# %% [markdown]
# 4. Top-k của từng retrieval branch.

# %% [markdown]
# 5. Score normalization method.

# %% [markdown]
# 6. Fusion weights.

# %% [markdown]
# 7. Position filter khi DB chỉ lưu bbox pixel nhưng không lưu image width/height.

# %% [markdown]
# 8. Hard-filter hay soft-boost mặc định cho object.
